# %% [markdown]
# #### Instructions
#
# #### Prioritize the MVP
#
# In the previous lab, you had to scrape data about "hot songs". It's critical to be on track with that part, as it was part of the request from the CTO.
#  - Done
#
# If you couldn't finish the first lab, use this time to go back there.
#
# **User experience:**
#
# - What happens if the user inputs a song that doesn't exist?
# - We return an error message
# - What do we do with songs that have the same name, but a different artist?
# - We can ask the user to type the artist name
# - How do we deal with typos?
#
# **Architecture:**
#
# - Do we build the interaction with the user in the same notebook as the web-scraping?
# - Where do we store the scraped songs?
#
# **Scheduling / Automation:**
#
# - Should we scrape billboard / wikipedia every time a user sends a request?
#
# **Testing:**
#
# - Does it work when you test it with a real user (a colleague)?
#
# Chances are that more issues will appear, and that not all of them will be solved during this session. But what's important is that the issues have been identified.

# %%
def billboard_scraping():
    # 1. import libraries
    from bs4 import BeautifulSoup
    import requests
    import pandas as pd

    # 2. find url and store it in a variable
    url = "https://www.billboard.com/charts/hot-100/"

    # 3. download html with a get request 
    response = requests.get(url)

    # 4.1. parse html (create the 'soup')
    soup = BeautifulSoup(response.content, "html.parser")

    s = soup.find_all('h3', class_='c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only')

    t = soup.find_all('h3', class_='c-title a-font-primary-bold-l a-font-primary-bold-m@mobile-max lrv-u-color-black u-color-white@mobile-max lrv-u-margin-r-150')
    
    #5 iterate over list
    title = []
    title.append(t[0].get_text().replace("\n",""))
    for i in range(len(s)):
        text = str(s[i].get_text()).replace("\n", "")
        title.append(text)

    s = soup.find_all('span', class_='c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only')

    t = soup.find_all('p', class_='c-tagline a-font-primary-l a-font-primary-m@mobile-max lrv-u-color-black u-color-white@mobile-max lrv-u-margin-tb-00 lrv-u-padding-t-025 lrv-u-margin-r-150')

    artist = []
    artist.append(t[0].get_text().replace("\n",""))
    for i in range(len(s)):
        text = str(s[i].get_text()).replace("\n", "")
        artist.append(text)
    
    #6 create the dataframe
    billboard = pd.DataFrame({"title":title,
                           "artist":artist,
                          })

    return billboard

billboard_scraping()
# Out:
#                         title  \
# 0   We Don't Talk About Bruno
# 1       Do We Have A Problem?
# 2                  Easy On Me
# 3                  Heat Waves
# 4                        Stay
# ..                        ...
# 95                       Iffy
# 96              When I'm Gone
# 97                 Fair Trade
# 98              Megan's Piano
# 99            Moth To A Flame
#
#                                                artist
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...
# 1                              Nicki Minaj X Lil Baby
# 2                                               Adele
# 3                                       Glass Animals
# 4                       The Kid LAROI & Justin Bieber
# ..                                                ...
# 95                                        Chris Brown
# 96                                Alesso / Katy Perry
# 97                       Drake Featuring Travis Scott
# 98                                Megan Thee Stallion
# 99                   Swedish House Mafia & The Weeknd
#
# [100 rows x 2 columns]

# %%
billboard_hot_100 = billboard_scraping()

# %%
billboard_hot_100
# Out:
#                         title  \
# 0   We Don't Talk About Bruno
# 1       Do We Have A Problem?
# 2                  Easy On Me
# 3                  Heat Waves
# 4                        Stay
# ..                        ...
# 95                       Iffy
# 96              When I'm Gone
# 97                 Fair Trade
# 98              Megan's Piano
# 99            Moth To A Flame
#
#                                                artist
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...
# 1                              Nicki Minaj X Lil Baby
# 2                                               Adele
# 3                                       Glass Animals
# 4                       The Kid LAROI & Justin Bieber
# ..                                                ...
# 95                                        Chris Brown
# 96                                Alesso / Katy Perry
# 97                       Drake Featuring Travis Scott
# 98                                Megan Thee Stallion
# 99                   Swedish House Mafia & The Weeknd
#
# [100 rows x 2 columns]

# %%
def user_input():
    x = input("Please enter the title of a song: ")
    
    return x

# %%
def lowercase_values(dataframe):
    for column_name in list(dataframe.select_dtypes(include='object').columns.values):
        dataframe[column_name] = dataframe[column_name].str.lower()

# %%
#The goal here is to print the title and the artist if the researched song is in the billboard hot 100
#if method

import pandas as pd
from Levenshtein import distance as lev

#df2 = pd.DataFrame([["easy on me","not adele"]],columns=['title', 'artist'])
#billboard_hot_100 = pd.concat([billboard_hot_100, df2],ignore_index=True)
x = user_input()
lowercase_values(billboard_hot_100)
my_list = list(billboard_hot_100["title"])
x = str.lower(x)
for title in billboard_hot_100["title"]:
    if lev(title,x) < 3:
        x = title
if billboard_hot_100[billboard_hot_100["title"] == x].shape[0] > 1:
    print(billboard_hot_100[billboard_hot_100["title"] == x])
    y = int(input("Please enter the number next to the song: "))
    song = billboard_hot_100["title"][y]
    artist = billboard_hot_100["artist"][y]
    print("Your selected song is: "+ song +" from "+ artist)
    reco = billboard_hot_100.sample(n = 1)
    song = list(reco["title"])[0]
    artist = list(reco["artist"])[0]
    print("You should listen to: "+ song +" from "+ artist)
elif x in my_list:
    song = list(billboard_hot_100["title"][billboard_hot_100["title"] == str.lower(x)])[0]
    artist = list(billboard_hot_100["artist"][billboard_hot_100["title"] == str.lower(x)])[0]
    print("Your selected song is: "+ song +" from "+ artist)
    reco = billboard_hot_100.sample(n = 1)
    song = list(reco["title"])[0]
    artist = list(reco["artist"])[0]
    print("You should listen to: "+ song +" from "+ artist)
else:
    print("The song is not in the hot list")
# Out:
# Please enter the title of a song: test
# The song is not in the hot list

# %% [markdown]
# # Lab | API wrappers - Create your collection of songs & audio features
#
#
# #### Instructions
#
#
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster.
# The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %% [markdown]
# Billboard Hot 100 playlist
#
# https://open.spotify.com/playlist/6UeSakyzhiEt4NB3UAd6NQ?si=19d7543e2fb94fe6
#
# Chill Pill playlist
#
# https://open.spotify.com/playlist/7aZ5mBWDDCNy7wmdCf4FCX?si=d28cf9ef49bd497a
#
# https://www.geeksforgeeks.org/append-list-of-dictionary-and-series-to-a-existing-pandas-dataframe-in-python/
#
# Longest Playlist on Spotify (10k songs)
#
# https://open.spotify.com/playlist/5S8SJdl1BDc0ugpkEvFsIL

# %%
import config

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

results = sp.search(q="Lose Yourself",limit=1,market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lose+Yourself&type=track&market=GB&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'},
#      'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4',
#      'id': '1rfORa9iYmocEsnnZGMVC4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec',
#        'width': 64}],
#      'name': 'Just Lose It',
#      'release_date': '2004-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 1,
#     'duration_ms': 322226,
#     'explicit': True,
#     'external_ids': {'isrc': 'USIR10211559'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'},
#     'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#     'id': '1v7L65Lzy0j0vdpRjJewt1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lose Yourself - From "8 Mile" Soundtrack',
#     'popularity': 79,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Lose+Yourself&type=track&market=GB&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 4147}}

# %% [markdown]
# import pprint
#
# pprint.pprint(playlist) to check the json file more clearly

# %%
import pandas as pd
df = pd.DataFrame({})
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

chillpill_tracks = get_playlist_tracks("spotify", "7aZ5mBWDDCNy7wmdCf4FCX")
chillpill_tracks
# Out:
# [{'added_at': '2020-01-14T14:23:30Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6K44xJeoORjgqFWovNnSkg'},
#     'href': 'https://api.spotify.com/v1/albums/6K44xJeoORjgqFWovNnSkg',
#     'id': '6K44xJeoORjgqFWovNnSkg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737392a38627de9efd21169116',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027392a38627de9efd21169116',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517392a38627de9efd21169116',
#       'width': 64}],
#     'name': 'Folha de Jurema',
#     'release_date': '2017-09-22',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:6K44xJeoORjgqFWovNnSkg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0OltT51j3hIkgaDJqqPzDn'},
#      'href': 'https://api.spotify.com/v1/artists/0OltT51j3hIkgaDJqqPzDn',
#      'id': '0OltT51j3hIkgaDJqqPzDn',
#      'name': 'Nicola Cruz',
#      'type': 'artist',
#      'uri': 'spotify:artist:0OltT51j3hIkgaDJqqPzDn'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5yPaj9fKegvkHQdfNo1i35'},
#      'href': 'https://api.spotify.com/v1/artists/5yPaj9fKegvkHQdfNo1i35',
#      'id': '5yPaj9fKegvkHQdfNo1i35',
#      'name': 'Salvador Araguaya',
#      'type': 'artist',
#      'uri': 'spotify:artist:5yPaj9fKegvkHQdfNo1i35'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/379N7T3a4nmax4XPxffDn1'},
#      'href': 'https://api.spotify.com/v1/artists/379N7T3a4nmax4XPxffDn1',
#      'id': '379N7T3a4nmax4XPxffDn1',
#      'name': 'Spaniol',
#      'type': 'artist',
#      'uri': 'spotify:artist:379N7T3a4nmax4XPxffDn1'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2uOgBTx0GFjWS205jRJZf6'},
#      'href': 'https://api.spotify.com/v1/artists/2uOgBTx0GFjWS205jRJZf6',
#      'id': '2uOgBTx0GFjWS205jRJZf6',
#      'name': 'Artéria FM',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uOgBTx0GFjWS205jRJZf6'}],
#    'disc_number': 1,
#    'duration_ms': 263688,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEZ651713345'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2RcrkBWCOWaX67jVDLgJr6'},
#    'href': 'https://api.spotify.com/v1/tracks/2RcrkBWCOWaX67jVDLgJr6',
#    'id': '2RcrkBWCOWaX67jVDLgJr6',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Folha de Jurema',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/52c10fd40b1e2099c27c53bfb82fd4151d711573?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2RcrkBWCOWaX67jVDLgJr6'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T13:27:40Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7rtM2wPKQlFpsm0C4qJlDk'},
#       'href': 'https://api.spotify.com/v1/artists/7rtM2wPKQlFpsm0C4qJlDk',
#       'id': '7rtM2wPKQlFpsm0C4qJlDk',
#       'name': 'Kendra Morris',
#       'type': 'artist',
#       'uri': 'spotify:artist:7rtM2wPKQlFpsm0C4qJlDk'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3dWQ2TtlpW3crGadeOldHe'},
#     'href': 'https://api.spotify.com/v1/albums/3dWQ2TtlpW3crGadeOldHe',
#     'id': '3dWQ2TtlpW3crGadeOldHe',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27311be7294d45ebeaeeac4dd78',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0211be7294d45ebeaeeac4dd78',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485111be7294d45ebeaeeac4dd78',
#       'width': 64}],
#     'name': 'Banshee',
#     'release_date': '2013-10-01',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3dWQ2TtlpW3crGadeOldHe'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7rtM2wPKQlFpsm0C4qJlDk'},
#      'href': 'https://api.spotify.com/v1/artists/7rtM2wPKQlFpsm0C4qJlDk',
#      'id': '7rtM2wPKQlFpsm0C4qJlDk',
#      'name': 'Kendra Morris',
#      'type': 'artist',
#      'uri': 'spotify:artist:7rtM2wPKQlFpsm0C4qJlDk'}],
#    'disc_number': 1,
#    'duration_ms': 226973,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMP4K1200012'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3GmYxpXRc62mj4SuJ4WEsl'},
#    'href': 'https://api.spotify.com/v1/tracks/3GmYxpXRc62mj4SuJ4WEsl',
#    'id': '3GmYxpXRc62mj4SuJ4WEsl',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2BDTl2NqhVQK0zc1nggCvO'},
#     'href': 'https://api.spotify.com/v1/tracks/2BDTl2NqhVQK0zc1nggCvO',
#     'id': '2BDTl2NqhVQK0zc1nggCvO',
#     'type': 'track',
#     'uri': 'spotify:track:2BDTl2NqhVQK0zc1nggCvO'},
#    'name': 'Banshee',
#    'popularity': 42,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ec21978c09bf59774a27ded699956f5247e0475a?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:3GmYxpXRc62mj4SuJ4WEsl'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T14:16:08Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2EMmqQQmszsCXfVfMRibOQ'},
#       'href': 'https://api.spotify.com/v1/artists/2EMmqQQmszsCXfVfMRibOQ',
#       'id': '2EMmqQQmszsCXfVfMRibOQ',
#       'name': 'La Fine Equipe',
#       'type': 'artist',
#       'uri': 'spotify:artist:2EMmqQQmszsCXfVfMRibOQ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5EnKfK3RZWFphBo1cVbPIC'},
#     'href': 'https://api.spotify.com/v1/albums/5EnKfK3RZWFphBo1cVbPIC',
#     'id': '5EnKfK3RZWFphBo1cVbPIC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27341a8dde960719de03b51f5ee',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0241a8dde960719de03b51f5ee',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485141a8dde960719de03b51f5ee',
#       'width': 64}],
#     'name': 'La Boulangerie 2 (La Fine Equipe & Friends)',
#     'release_date': '2011-06-27',
#     'release_date_precision': 'day',
#     'total_tracks': 33,
#     'type': 'album',
#     'uri': 'spotify:album:5EnKfK3RZWFphBo1cVbPIC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2EMmqQQmszsCXfVfMRibOQ'},
#      'href': 'https://api.spotify.com/v1/artists/2EMmqQQmszsCXfVfMRibOQ',
#      'id': '2EMmqQQmszsCXfVfMRibOQ',
#      'name': 'La Fine Equipe',
#      'type': 'artist',
#      'uri': 'spotify:artist:2EMmqQQmszsCXfVfMRibOQ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1cfsqRGB73Gt7hygNzOmFm'},
#      'href': 'https://api.spotify.com/v1/artists/1cfsqRGB73Gt7hygNzOmFm',
#      'id': '1cfsqRGB73Gt7hygNzOmFm',
#      'name': 'Saneyes',
#      'type': 'artist',
#      'uri': 'spotify:artist:1cfsqRGB73Gt7hygNzOmFm'}],
#    'disc_number': 1,
#    'duration_ms': 133893,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR1A91100177'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1pur8kv69XmZqA3uoMEYnH'},
#    'href': 'https://api.spotify.com/v1/tracks/1pur8kv69XmZqA3uoMEYnH',
#    'id': '1pur8kv69XmZqA3uoMEYnH',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Tourment d' amour",
#    'popularity': 58,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5a730e77f56d85e73e1b31b314b8ced54ec96187?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1pur8kv69XmZqA3uoMEYnH'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T13:25:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/536osqBGKzeozje8BfcGsa'},
#       'href': 'https://api.spotify.com/v1/artists/536osqBGKzeozje8BfcGsa',
#       'id': '536osqBGKzeozje8BfcGsa',
#       'name': 'Allen Stone',
#       'type': 'artist',
#       'uri': 'spotify:artist:536osqBGKzeozje8BfcGsa'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3p6Hpda8mtbni5cbgYnwyM'},
#     'href': 'https://api.spotify.com/v1/albums/3p6Hpda8mtbni5cbgYnwyM',
#     'id': '3p6Hpda8mtbni5cbgYnwyM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f6608a96c78b2b1857e68fb0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f6608a96c78b2b1857e68fb0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f6608a96c78b2b1857e68fb0',
#       'width': 64}],
#     'name': 'Million',
#     'release_date': '2015-05-05',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3p6Hpda8mtbni5cbgYnwyM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/536osqBGKzeozje8BfcGsa'},
#      'href': 'https://api.spotify.com/v1/artists/536osqBGKzeozje8BfcGsa',
#      'id': '536osqBGKzeozje8BfcGsa',
#      'name': 'Allen Stone',
#      'type': 'artist',
#      'uri': 'spotify:artist:536osqBGKzeozje8BfcGsa'}],
#    'disc_number': 1,
#    'duration_ms': 265520,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71402873'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6g6LjgaH5I23KOkLkJeGxE'},
#    'href': 'https://api.spotify.com/v1/tracks/6g6LjgaH5I23KOkLkJeGxE',
#    'id': '6g6LjgaH5I23KOkLkJeGxE',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4ByJErwKXoJwZXpzEE0NNU'},
#     'href': 'https://api.spotify.com/v1/tracks/4ByJErwKXoJwZXpzEE0NNU',
#     'id': '4ByJErwKXoJwZXpzEE0NNU',
#     'type': 'track',
#     'uri': 'spotify:track:4ByJErwKXoJwZXpzEE0NNU'},
#    'name': 'Million',
#    'popularity': 39,
#    'preview_url': 'https://p.scdn.co/mp3-preview/08347c392031a5167f15dd2bad1161db103e172e?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6g6LjgaH5I23KOkLkJeGxE'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T13:31:28Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24icoQNJSEWNu3XvqKBR68'},
#       'href': 'https://api.spotify.com/v1/artists/24icoQNJSEWNu3XvqKBR68',
#       'id': '24icoQNJSEWNu3XvqKBR68',
#       'name': 'Jordan Rakei',
#       'type': 'artist',
#       'uri': 'spotify:artist:24icoQNJSEWNu3XvqKBR68'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2uWJhbEKI42yC1GZR8GaXx'},
#     'href': 'https://api.spotify.com/v1/albums/2uWJhbEKI42yC1GZR8GaXx',
#     'id': '2uWJhbEKI42yC1GZR8GaXx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e574932c34ad8f5b64405f81',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e574932c34ad8f5b64405f81',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e574932c34ad8f5b64405f81',
#       'width': 64}],
#     'name': 'Groove Curse',
#     'release_date': '2014-08-15',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:2uWJhbEKI42yC1GZR8GaXx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24icoQNJSEWNu3XvqKBR68'},
#      'href': 'https://api.spotify.com/v1/artists/24icoQNJSEWNu3XvqKBR68',
#      'id': '24icoQNJSEWNu3XvqKBR68',
#      'name': 'Jordan Rakei',
#      'type': 'artist',
#      'uri': 'spotify:artist:24icoQNJSEWNu3XvqKBR68'}],
#    'disc_number': 1,
#    'duration_ms': 275826,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCABY1466013'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3fVoaJNF8ALQlL0MG5XpWa'},
#    'href': 'https://api.spotify.com/v1/tracks/3fVoaJNF8ALQlL0MG5XpWa',
#    'id': '3fVoaJNF8ALQlL0MG5XpWa',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3HnQE5qyk3egTWCreicuOf'},
#     'href': 'https://api.spotify.com/v1/tracks/3HnQE5qyk3egTWCreicuOf',
#     'id': '3HnQE5qyk3egTWCreicuOf',
#     'type': 'track',
#     'uri': 'spotify:track:3HnQE5qyk3egTWCreicuOf'},
#    'name': 'Alright',
#    'popularity': 58,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4ab3da1dc7bdd63e808582a80d9e3faefcf9563b?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:3fVoaJNF8ALQlL0MG5XpWa'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T16:06:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3mNygoyrEKLgo6sx0MzwOL'},
#       'href': 'https://api.spotify.com/v1/artists/3mNygoyrEKLgo6sx0MzwOL',
#       'id': '3mNygoyrEKLgo6sx0MzwOL',
#       'name': 'Ali Farka Touré',
#       'type': 'artist',
#       'uri': 'spotify:artist:3mNygoyrEKLgo6sx0MzwOL'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2MSgPFGGgIn5EqLezjLpt9'},
#     'href': 'https://api.spotify.com/v1/albums/2MSgPFGGgIn5EqLezjLpt9',
#     'id': '2MSgPFGGgIn5EqLezjLpt9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734209569110ce50ca88e1dc46',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024209569110ce50ca88e1dc46',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514209569110ce50ca88e1dc46',
#       'width': 64}],
#     'name': 'Talking Timbuktu (with Ry Cooder)',
#     'release_date': '1994-03-28',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:2MSgPFGGgIn5EqLezjLpt9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3mNygoyrEKLgo6sx0MzwOL'},
#      'href': 'https://api.spotify.com/v1/artists/3mNygoyrEKLgo6sx0MzwOL',
#      'id': '3mNygoyrEKLgo6sx0MzwOL',
#      'name': 'Ali Farka Touré',
#      'type': 'artist',
#      'uri': 'spotify:artist:3mNygoyrEKLgo6sx0MzwOL'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1CPwHx5lgVxv0rfcp7UXLx'},
#      'href': 'https://api.spotify.com/v1/artists/1CPwHx5lgVxv0rfcp7UXLx',
#      'id': '1CPwHx5lgVxv0rfcp7UXLx',
#      'name': 'Ry Cooder',
#      'type': 'artist',
#      'uri': 'spotify:artist:1CPwHx5lgVxv0rfcp7UXLx'}],
#    'disc_number': 1,
#    'duration_ms': 429973,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBGU0640009'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3c6wivu78aLN7ZXp8UbpaI'},
#    'href': 'https://api.spotify.com/v1/tracks/3c6wivu78aLN7ZXp8UbpaI',
#    'id': '3c6wivu78aLN7ZXp8UbpaI',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7vzhCpNntdmzI3yop3UckE'},
#     'href': 'https://api.spotify.com/v1/tracks/7vzhCpNntdmzI3yop3UckE',
#     'id': '7vzhCpNntdmzI3yop3UckE',
#     'type': 'track',
#     'uri': 'spotify:track:7vzhCpNntdmzI3yop3UckE'},
#    'name': 'Ai Du (with Ry Cooder)',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6a83fd1b535cd073368ecbb70392c20bb238dcbe?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:3c6wivu78aLN7ZXp8UbpaI'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T13:28:27Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2GLETs2JWEl74J8LPvECwf'},
#     'href': 'https://api.spotify.com/v1/albums/2GLETs2JWEl74J8LPvECwf',
#     'id': '2GLETs2JWEl74J8LPvECwf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c7af862b36131bcc607b681d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c7af862b36131bcc607b681d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c7af862b36131bcc607b681d',
#       'width': 64}],
#     'name': '12 Years A Slave (Music From and Inspired by the Motion Picture)',
#     'release_date': '2013-11-01',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:2GLETs2JWEl74J8LPvECwf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Dy94lW3txJhWQHqNXP1BT'},
#      'href': 'https://api.spotify.com/v1/artists/0Dy94lW3txJhWQHqNXP1BT',
#      'id': '0Dy94lW3txJhWQHqNXP1BT',
#      'name': 'Laura Mvula',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Dy94lW3txJhWQHqNXP1BT'}],
#    'disc_number': 1,
#    'duration_ms': 270466,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBARL1301345'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/51zSqXbTSFJMPlrNNDhbEt'},
#    'href': 'https://api.spotify.com/v1/tracks/51zSqXbTSFJMPlrNNDhbEt',
#    'id': '51zSqXbTSFJMPlrNNDhbEt',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Little Girl Blue',
#    'popularity': 27,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cbafcffb2e174adc9b61ab7d95b763e422daefa6?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:51zSqXbTSFJMPlrNNDhbEt'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T16:19:46Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rqlONGmPuP2wJVSfliLBI'},
#       'href': 'https://api.spotify.com/v1/artists/6rqlONGmPuP2wJVSfliLBI',
#       'id': '6rqlONGmPuP2wJVSfliLBI',
#       'name': 'Peter Fox',
#       'type': 'artist',
#       'uri': 'spotify:artist:6rqlONGmPuP2wJVSfliLBI'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6cEVfMd0XVocPbRrYkVY5H'},
#     'href': 'https://api.spotify.com/v1/albums/6cEVfMd0XVocPbRrYkVY5H',
#     'id': '6cEVfMd0XVocPbRrYkVY5H',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739061a4e47413aff8f58a3c9c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029061a4e47413aff8f58a3c9c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519061a4e47413aff8f58a3c9c',
#       'width': 64}],
#     'name': 'Stadtaffe',
#     'release_date': '2008-09-26',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6cEVfMd0XVocPbRrYkVY5H'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rqlONGmPuP2wJVSfliLBI'},
#      'href': 'https://api.spotify.com/v1/artists/6rqlONGmPuP2wJVSfliLBI',
#      'id': '6rqlONGmPuP2wJVSfliLBI',
#      'name': 'Peter Fox',
#      'type': 'artist',
#      'uri': 'spotify:artist:6rqlONGmPuP2wJVSfliLBI'}],
#    'disc_number': 1,
#    'duration_ms': 216000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEA620800624'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7A4KdLy1DXOOC5fhIdDuHz'},
#    'href': 'https://api.spotify.com/v1/tracks/7A4KdLy1DXOOC5fhIdDuHz',
#    'id': '7A4KdLy1DXOOC5fhIdDuHz',
#    'is_local': False,
#    'is_playable': False,
#    'name': 'Haus am See',
#    'popularity': 64,
#    'preview_url': None,
#    'restrictions': {'reason': 'market'},
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:7A4KdLy1DXOOC5fhIdDuHz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T15:50:38Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/462T0buQ5ScBUQCRpodDRf'},
#       'href': 'https://api.spotify.com/v1/artists/462T0buQ5ScBUQCRpodDRf',
#       'id': '462T0buQ5ScBUQCRpodDRf',
#       'name': 'Charles Bradley',
#       'type': 'artist',
#       'uri': 'spotify:artist:462T0buQ5ScBUQCRpodDRf'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3rimYQyKq7BatxuUoPIBrb'},
#     'href': 'https://api.spotify.com/v1/albums/3rimYQyKq7BatxuUoPIBrb',
#     'id': '3rimYQyKq7BatxuUoPIBrb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27300da03216eb2a67144e8837c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0200da03216eb2a67144e8837c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485100da03216eb2a67144e8837c',
#       'width': 64}],
#     'name': 'Victim of Love',
#     'release_date': '2013-04-02',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:3rimYQyKq7BatxuUoPIBrb'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/462T0buQ5ScBUQCRpodDRf'},
#      'href': 'https://api.spotify.com/v1/artists/462T0buQ5ScBUQCRpodDRf',
#      'id': '462T0buQ5ScBUQCRpodDRf',
#      'name': 'Charles Bradley',
#      'type': 'artist',
#      'uri': 'spotify:artist:462T0buQ5ScBUQCRpodDRf'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1PryMSya1JnSAlcwYawCxp'},
#      'href': 'https://api.spotify.com/v1/artists/1PryMSya1JnSAlcwYawCxp',
#      'id': '1PryMSya1JnSAlcwYawCxp',
#      'name': 'Menahan Street Band',
#      'type': 'artist',
#      'uri': 'spotify:artist:1PryMSya1JnSAlcwYawCxp'}],
#    'disc_number': 1,
#    'duration_ms': 222370,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US4GZ1303101'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2aWr9QRr0pSmYFH04zngiP'},
#    'href': 'https://api.spotify.com/v1/tracks/2aWr9QRr0pSmYFH04zngiP',
#    'id': '2aWr9QRr0pSmYFH04zngiP',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0Qjgq243iP5w5Kumk2gIYb'},
#     'href': 'https://api.spotify.com/v1/tracks/0Qjgq243iP5w5Kumk2gIYb',
#     'id': '0Qjgq243iP5w5Kumk2gIYb',
#     'type': 'track',
#     'uri': 'spotify:track:0Qjgq243iP5w5Kumk2gIYb'},
#    'name': 'Strictly Reserved for You',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1f458f636fdc0b5f63c7840ffc99b8df7202413f?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2aWr9QRr0pSmYFH04zngiP'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T20:16:42Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4lujUKeO6nQAJXpq37Epn7'},
#       'href': 'https://api.spotify.com/v1/artists/4lujUKeO6nQAJXpq37Epn7',
#       'id': '4lujUKeO6nQAJXpq37Epn7',
#       'name': 'Son Little',
#       'type': 'artist',
#       'uri': 'spotify:artist:4lujUKeO6nQAJXpq37Epn7'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2jGQieA1EggldcxFAiQHjJ'},
#     'href': 'https://api.spotify.com/v1/albums/2jGQieA1EggldcxFAiQHjJ',
#     'id': '2jGQieA1EggldcxFAiQHjJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d090f49c5ca5b15746c4bc91',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d090f49c5ca5b15746c4bc91',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d090f49c5ca5b15746c4bc91',
#       'width': 64}],
#     'name': 'Son Little (Deluxe Edition)',
#     'release_date': '2015-10-16',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:2jGQieA1EggldcxFAiQHjJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4lujUKeO6nQAJXpq37Epn7'},
#      'href': 'https://api.spotify.com/v1/artists/4lujUKeO6nQAJXpq37Epn7',
#      'id': '4lujUKeO6nQAJXpq37Epn7',
#      'name': 'Son Little',
#      'type': 'artist',
#      'uri': 'spotify:artist:4lujUKeO6nQAJXpq37Epn7'}],
#    'disc_number': 1,
#    'duration_ms': 235520,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USEP41327001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7cnt5XipD83fUsvnhQBtwA'},
#    'href': 'https://api.spotify.com/v1/tracks/7cnt5XipD83fUsvnhQBtwA',
#    'id': '7cnt5XipD83fUsvnhQBtwA',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6wZQs6TfQ0xCwFW1lrLr1f'},
#     'href': 'https://api.spotify.com/v1/tracks/6wZQs6TfQ0xCwFW1lrLr1f',
#     'id': '6wZQs6TfQ0xCwFW1lrLr1f',
#     'type': 'track',
#     'uri': 'spotify:track:6wZQs6TfQ0xCwFW1lrLr1f'},
#    'name': 'Cross My Heart',
#    'popularity': 30,
#    'preview_url': 'https://p.scdn.co/mp3-preview/18fb02935b2737dcb23f11cbd30c2697ca993343?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 14,
#    'type': 'track',
#    'uri': 'spotify:track:7cnt5XipD83fUsvnhQBtwA'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T13:30:46Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0bzfPKdbXL5ezYW2z3UGQj'},
#       'href': 'https://api.spotify.com/v1/artists/0bzfPKdbXL5ezYW2z3UGQj',
#       'id': '0bzfPKdbXL5ezYW2z3UGQj',
#       'name': 'Michael Kiwanuka',
#       'type': 'artist',
#       'uri': 'spotify:artist:0bzfPKdbXL5ezYW2z3UGQj'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6b7DeWxueaZY0NNReD6TrK'},
#     'href': 'https://api.spotify.com/v1/albums/6b7DeWxueaZY0NNReD6TrK',
#     'id': '6b7DeWxueaZY0NNReD6TrK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cf3cd9588ec89ab911b70780',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cf3cd9588ec89ab911b70780',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cf3cd9588ec89ab911b70780',
#       'width': 64}],
#     'name': 'Home Again (Deluxe Version)',
#     'release_date': '2012-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:6b7DeWxueaZY0NNReD6TrK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0bzfPKdbXL5ezYW2z3UGQj'},
#      'href': 'https://api.spotify.com/v1/artists/0bzfPKdbXL5ezYW2z3UGQj',
#      'id': '0bzfPKdbXL5ezYW2z3UGQj',
#      'name': 'Michael Kiwanuka',
#      'type': 'artist',
#      'uri': 'spotify:artist:0bzfPKdbXL5ezYW2z3UGQj'}],
#    'disc_number': 1,
#    'duration_ms': 209919,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71110209'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5yGVHzJ2Se8pDzR7FIYUlU'},
#    'href': 'https://api.spotify.com/v1/tracks/5yGVHzJ2Se8pDzR7FIYUlU',
#    'id': '5yGVHzJ2Se8pDzR7FIYUlU',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Home Again',
#    'popularity': 66,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:5yGVHzJ2Se8pDzR7FIYUlU'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-08T15:19:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4FpJcNgOvIpSBeJgRg3OfN'},
#       'href': 'https://api.spotify.com/v1/artists/4FpJcNgOvIpSBeJgRg3OfN',
#       'id': '4FpJcNgOvIpSBeJgRg3OfN',
#       'name': 'Orelsan',
#       'type': 'artist',
#       'uri': 'spotify:artist:4FpJcNgOvIpSBeJgRg3OfN'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5GfsaNstrK8rszTX5XYtXU'},
#     'href': 'https://api.spotify.com/v1/albums/5GfsaNstrK8rszTX5XYtXU',
#     'id': '5GfsaNstrK8rszTX5XYtXU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27342a91184c215f8a95b5f77ec',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0242a91184c215f8a95b5f77ec',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485142a91184c215f8a95b5f77ec',
#       'width': 64}],
#     'name': 'Le chant des sirènes',
#     'release_date': '2011-09-26',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5GfsaNstrK8rszTX5XYtXU'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4FpJcNgOvIpSBeJgRg3OfN'},
#      'href': 'https://api.spotify.com/v1/artists/4FpJcNgOvIpSBeJgRg3OfN',
#      'id': '4FpJcNgOvIpSBeJgRg3OfN',
#      'name': 'Orelsan',
#      'type': 'artist',
#      'uri': 'spotify:artist:4FpJcNgOvIpSBeJgRg3OfN'}],
#    'disc_number': 1,
#    'duration_ms': 219865,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR6F31101390'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3IM7zXywZ6sRTtkRjRLxJ8'},
#    'href': 'https://api.spotify.com/v1/tracks/3IM7zXywZ6sRTtkRjRLxJ8',
#    'id': '3IM7zXywZ6sRTtkRjRLxJ8',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'La terre est ronde',
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/07ff9ea25bc6f7d14e1e85b4ef3b459ab10dec00?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:3IM7zXywZ6sRTtkRjRLxJ8'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T20:13:14Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6uZHP2IZqZWsBPnt2aGisY'},
#       'href': 'https://api.spotify.com/v1/artists/6uZHP2IZqZWsBPnt2aGisY',
#       'id': '6uZHP2IZqZWsBPnt2aGisY',
#       'name': 'Silk Rhodes',
#       'type': 'artist',
#       'uri': 'spotify:artist:6uZHP2IZqZWsBPnt2aGisY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3i1kIb5NncLgLIU86ju8jr'},
#     'href': 'https://api.spotify.com/v1/albums/3i1kIb5NncLgLIU86ju8jr',
#     'id': '3i1kIb5NncLgLIU86ju8jr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273affac3f0787426f8f8f53100',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02affac3f0787426f8f8f53100',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851affac3f0787426f8f8f53100',
#       'width': 64}],
#     'name': 'Silk Rhodes',
#     'release_date': '2014-12-02',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3i1kIb5NncLgLIU86ju8jr'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6uZHP2IZqZWsBPnt2aGisY'},
#      'href': 'https://api.spotify.com/v1/artists/6uZHP2IZqZWsBPnt2aGisY',
#      'id': '6uZHP2IZqZWsBPnt2aGisY',
#      'name': 'Silk Rhodes',
#      'type': 'artist',
#      'uri': 'spotify:artist:6uZHP2IZqZWsBPnt2aGisY'}],
#    'disc_number': 1,
#    'duration_ms': 191424,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US2S71451002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3t6gmz9lT8L9cSqWahpo1r'},
#    'href': 'https://api.spotify.com/v1/tracks/3t6gmz9lT8L9cSqWahpo1r',
#    'id': '3t6gmz9lT8L9cSqWahpo1r',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/52jCt6iAEPOzE8ZIjtdZVj'},
#     'href': 'https://api.spotify.com/v1/tracks/52jCt6iAEPOzE8ZIjtdZVj',
#     'id': '52jCt6iAEPOzE8ZIjtdZVj',
#     'type': 'track',
#     'uri': 'spotify:track:52jCt6iAEPOzE8ZIjtdZVj'},
#    'name': 'Pains',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/157eef6b48663483c585fca92a5069eada789803?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3t6gmz9lT8L9cSqWahpo1r'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T13:27:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6sz0k1q2aEtG5dxEgr4YWV'},
#       'href': 'https://api.spotify.com/v1/artists/6sz0k1q2aEtG5dxEgr4YWV',
#       'id': '6sz0k1q2aEtG5dxEgr4YWV',
#       'name': 'Rokia Traoré',
#       'type': 'artist',
#       'uri': 'spotify:artist:6sz0k1q2aEtG5dxEgr4YWV'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5gCev1aMAHiG6qmS32mfzj'},
#     'href': 'https://api.spotify.com/v1/albums/5gCev1aMAHiG6qmS32mfzj',
#     'id': '5gCev1aMAHiG6qmS32mfzj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273143fc810bf25e1f7c431bf32',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02143fc810bf25e1f7c431bf32',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851143fc810bf25e1f7c431bf32',
#       'width': 64}],
#     'name': 'Beautiful Africa',
#     'release_date': '2013-04-01',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:5gCev1aMAHiG6qmS32mfzj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6sz0k1q2aEtG5dxEgr4YWV'},
#      'href': 'https://api.spotify.com/v1/artists/6sz0k1q2aEtG5dxEgr4YWV',
#      'id': '6sz0k1q2aEtG5dxEgr4YWV',
#      'name': 'Rokia Traoré',
#      'type': 'artist',
#      'uri': 'spotify:artist:6sz0k1q2aEtG5dxEgr4YWV'}],
#    'disc_number': 1,
#    'duration_ms': 386373,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRYAT1300040'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3rCJPCJTJRUxvCduWDVprx'},
#    'href': 'https://api.spotify.com/v1/tracks/3rCJPCJTJRUxvCduWDVprx',
#    'id': '3rCJPCJTJRUxvCduWDVprx',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ka moun kè',
#    'popularity': 48,
#    'preview_url': 'https://p.scdn.co/mp3-preview/29c4bf7649cfa8161dd15d4155c4d986ff129e00?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:3rCJPCJTJRUxvCduWDVprx'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T13:58:15Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xUZ4069zcyBM4Bn10NQ1c'},
#       'href': 'https://api.spotify.com/v1/artists/7xUZ4069zcyBM4Bn10NQ1c',
#       'id': '7xUZ4069zcyBM4Bn10NQ1c',
#       'name': 'Ásgeir',
#       'type': 'artist',
#       'uri': 'spotify:artist:7xUZ4069zcyBM4Bn10NQ1c'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4Egxt2rlCo4YONCrUAUF0W'},
#     'href': 'https://api.spotify.com/v1/albums/4Egxt2rlCo4YONCrUAUF0W',
#     'id': '4Egxt2rlCo4YONCrUAUF0W',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734eaa32e8e1e57dbb88062da0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024eaa32e8e1e57dbb88062da0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514eaa32e8e1e57dbb88062da0',
#       'width': 64}],
#     'name': 'Dýrð Í Dauðaþögn',
#     'release_date': '2012-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4Egxt2rlCo4YONCrUAUF0W'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xUZ4069zcyBM4Bn10NQ1c'},
#      'href': 'https://api.spotify.com/v1/artists/7xUZ4069zcyBM4Bn10NQ1c',
#      'id': '7xUZ4069zcyBM4Bn10NQ1c',
#      'name': 'Ásgeir',
#      'type': 'artist',
#      'uri': 'spotify:artist:7xUZ4069zcyBM4Bn10NQ1c'}],
#    'disc_number': 1,
#    'duration_ms': 213720,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBTF1300016'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4BtEGOZ0QwfT2HOY3Ly3Sc'},
#    'href': 'https://api.spotify.com/v1/tracks/4BtEGOZ0QwfT2HOY3Ly3Sc',
#    'id': '4BtEGOZ0QwfT2HOY3Ly3Sc',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/67JjlJUDui4ERQdexDJsvb'},
#     'href': 'https://api.spotify.com/v1/tracks/67JjlJUDui4ERQdexDJsvb',
#     'id': '67JjlJUDui4ERQdexDJsvb',
#     'type': 'track',
#     'uri': 'spotify:track:67JjlJUDui4ERQdexDJsvb'},
#    'name': 'Leyndarmál',
#    'popularity': 37,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4BtEGOZ0QwfT2HOY3Ly3Sc'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T16:44:57Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#       'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#       'id': '6Q192DXotxtaysaqNPy5yR',
#       'name': 'Amy Winehouse',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0E4xv5gPjykrwBgBZzI8XG'},
#     'href': 'https://api.spotify.com/v1/albums/0E4xv5gPjykrwBgBZzI8XG',
#     'id': '0E4xv5gPjykrwBgBZzI8XG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27376ffb5b5ab045d22c81235c1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0276ffb5b5ab045d22c81235c1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485176ffb5b5ab045d22c81235c1',
#       'width': 64}],
#     'name': 'Back To Black (Deluxe Edition)',
#     'release_date': '2006',
#     'release_date_precision': 'year',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:0E4xv5gPjykrwBgBZzI8XG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#      'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#      'id': '6Q192DXotxtaysaqNPy5yR',
#      'name': 'Amy Winehouse',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'}],
#    'disc_number': 2,
#    'duration_ms': 233733,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM70702678'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6nLvaCZFR1wEzW3sIKpsnr'},
#    'href': 'https://api.spotify.com/v1/tracks/6nLvaCZFR1wEzW3sIKpsnr',
#    'id': '6nLvaCZFR1wEzW3sIKpsnr',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Valerie - Live At BBC Radio 1 Live Lounge, London / 2007',
#    'popularity': 77,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6nLvaCZFR1wEzW3sIKpsnr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T13:52:42Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#       'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#       'id': '2wY79sveU1sp5g7SokKOiI',
#       'name': 'Sam Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/08jWgM4vSkTose4blKBWov'},
#     'href': 'https://api.spotify.com/v1/albums/08jWgM4vSkTose4blKBWov',
#     'id': '08jWgM4vSkTose4blKBWov',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b11bdc91cb9ac6b14f5c1dae',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b11bdc91cb9ac6b14f5c1dae',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b11bdc91cb9ac6b14f5c1dae',
#       'width': 64}],
#     'name': 'In The Lonely Hour',
#     'release_date': '2014-05-26',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:08jWgM4vSkTose4blKBWov'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#      'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#      'id': '2wY79sveU1sp5g7SokKOiI',
#      'name': 'Sam Smith',
#      'type': 'artist',
#      'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#    'disc_number': 1,
#    'duration_ms': 239316,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71308836'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7795WJLVKJoAyVoOtCWqXN'},
#    'href': 'https://api.spotify.com/v1/tracks/7795WJLVKJoAyVoOtCWqXN',
#    'id': '7795WJLVKJoAyVoOtCWqXN',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1VbhR6D6zUoSTBzvnRonXO'},
#     'href': 'https://api.spotify.com/v1/tracks/1VbhR6D6zUoSTBzvnRonXO',
#     'id': '1VbhR6D6zUoSTBzvnRonXO',
#     'type': 'track',
#     'uri': 'spotify:track:1VbhR6D6zUoSTBzvnRonXO'},
#    'name': "I'm Not The Only One",
#    'popularity': 84,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:7795WJLVKJoAyVoOtCWqXN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-07-12T13:34:12Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#       'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#       'id': '16GcWuvvybAoaHr0NqT8Eh',
#       'name': 'Alabama Shakes',
#       'type': 'artist',
#       'uri': 'spotify:artist:16GcWuvvybAoaHr0NqT8Eh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3q6QbjJGKQpDXT6XDZij6Y'},
#     'href': 'https://api.spotify.com/v1/albums/3q6QbjJGKQpDXT6XDZij6Y',
#     'id': '3q6QbjJGKQpDXT6XDZij6Y',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d5abe87cecc0f78512973a57',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d5abe87cecc0f78512973a57',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d5abe87cecc0f78512973a57',
#       'width': 64}],
#     'name': 'Sound & Color (Deluxe Edition)',
#     'release_date': '2015',
#     'release_date_precision': 'year',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:3q6QbjJGKQpDXT6XDZij6Y'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/16GcWuvvybAoaHr0NqT8Eh'},
#      'href': 'https://api.spotify.com/v1/artists/16GcWuvvybAoaHr0NqT8Eh',
#      'id': '16GcWuvvybAoaHr0NqT8Eh',
#      'name': 'Alabama Shakes',
#      'type': 'artist',
# ...
#    'is_playable': True,
#    'name': 'Fly Me To The Moon',
#    'popularity': 62,
#    'preview_url': None,
#    'track': True,
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:1PVTvvxpSkyJWemW1CwVVk'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-24T18:00:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nDNDLcZuSto4k9u4AbcLB'},
#       'href': 'https://api.spotify.com/v1/artists/3nDNDLcZuSto4k9u4AbcLB',
#       'id': '3nDNDLcZuSto4k9u4AbcLB',
#       'name': 'Marteria',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nDNDLcZuSto4k9u4AbcLB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6Ttnb4f8aPy7ytDJqV10FT'},
#     'href': 'https://api.spotify.com/v1/albums/6Ttnb4f8aPy7ytDJqV10FT',
#     'id': '6Ttnb4f8aPy7ytDJqV10FT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cd920ed90a9f89c9ba2e86c3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cd920ed90a9f89c9ba2e86c3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cd920ed90a9f89c9ba2e86c3',
#       'width': 64}],
#     'name': 'Zum Glück in die Zukunft II',
#     'release_date': '2014-01-31',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:6Ttnb4f8aPy7ytDJqV10FT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nDNDLcZuSto4k9u4AbcLB'},
#      'href': 'https://api.spotify.com/v1/artists/3nDNDLcZuSto4k9u4AbcLB',
#      'id': '3nDNDLcZuSto4k9u4AbcLB',
#      'name': 'Marteria',
#      'type': 'artist',
#      'uri': 'spotify:artist:3nDNDLcZuSto4k9u4AbcLB'}],
#    'disc_number': 1,
#    'duration_ms': 229653,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEQ321300474'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6ngfhauAytTZsaQgZyJIeK'},
#    'href': 'https://api.spotify.com/v1/tracks/6ngfhauAytTZsaQgZyJIeK',
#    'id': '6ngfhauAytTZsaQgZyJIeK',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'OMG!',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2310e753023b43cb7896daecd207bd55336e7d60?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:6ngfhauAytTZsaQgZyJIeK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-26T20:09:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3T5VmqTVAlLU7X0HKfCqY5'},
#       'href': 'https://api.spotify.com/v1/artists/3T5VmqTVAlLU7X0HKfCqY5',
#       'id': '3T5VmqTVAlLU7X0HKfCqY5',
#       'name': 'Minuit',
#       'type': 'artist',
#       'uri': 'spotify:artist:3T5VmqTVAlLU7X0HKfCqY5'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2ZZiUqmOAdG2odHhT3rmlo'},
#     'href': 'https://api.spotify.com/v1/albums/2ZZiUqmOAdG2odHhT3rmlo',
#     'id': '2ZZiUqmOAdG2odHhT3rmlo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735cdfc4f434edab9b94dde313',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025cdfc4f434edab9b94dde313',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515cdfc4f434edab9b94dde313',
#       'width': 64}],
#     'name': 'Vertigo',
#     'release_date': '2018-10-19',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2ZZiUqmOAdG2odHhT3rmlo'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3T5VmqTVAlLU7X0HKfCqY5'},
#      'href': 'https://api.spotify.com/v1/artists/3T5VmqTVAlLU7X0HKfCqY5',
#      'id': '3T5VmqTVAlLU7X0HKfCqY5',
#      'name': 'Minuit',
#      'type': 'artist',
#      'uri': 'spotify:artist:3T5VmqTVAlLU7X0HKfCqY5'}],
#    'disc_number': 1,
#    'duration_ms': 236520,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR6P11801100'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2J3bOjsCkPbriZaKz0H3xp'},
#    'href': 'https://api.spotify.com/v1/tracks/2J3bOjsCkPbriZaKz0H3xp',
#    'id': '2J3bOjsCkPbriZaKz0H3xp',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Paris Tropical',
#    'popularity': 36,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fd46bd10cabb5daa979633a690c97dee54670ea8?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2J3bOjsCkPbriZaKz0H3xp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-08-12T15:34:29Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0xHa28taiElkcQf9o3z76g'},
#       'href': 'https://api.spotify.com/v1/artists/0xHa28taiElkcQf9o3z76g',
#       'id': '0xHa28taiElkcQf9o3z76g',
#       'name': 'Static & Ben El',
#       'type': 'artist',
#       'uri': 'spotify:artist:0xHa28taiElkcQf9o3z76g'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z4afeDmHFxPmJorIwupbZ'},
#       'href': 'https://api.spotify.com/v1/artists/4Z4afeDmHFxPmJorIwupbZ',
#       'id': '4Z4afeDmHFxPmJorIwupbZ',
#       'name': 'Netta',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z4afeDmHFxPmJorIwupbZ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6isaVgYKgKOhbRSNppMkGx'},
#     'href': 'https://api.spotify.com/v1/albums/6isaVgYKgKOhbRSNppMkGx',
#     'id': '6isaVgYKgKOhbRSNppMkGx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ea60965b4841390ad5cbcce6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ea60965b4841390ad5cbcce6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ea60965b4841390ad5cbcce6',
#       'width': 64}],
#     'name': 'אפס מאמץ',
#     'release_date': '2021-06-30',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6isaVgYKgKOhbRSNppMkGx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0xHa28taiElkcQf9o3z76g'},
#      'href': 'https://api.spotify.com/v1/artists/0xHa28taiElkcQf9o3z76g',
#      'id': '0xHa28taiElkcQf9o3z76g',
#      'name': 'Static & Ben El',
#      'type': 'artist',
#      'uri': 'spotify:artist:0xHa28taiElkcQf9o3z76g'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z4afeDmHFxPmJorIwupbZ'},
#      'href': 'https://api.spotify.com/v1/artists/4Z4afeDmHFxPmJorIwupbZ',
#      'id': '4Z4afeDmHFxPmJorIwupbZ',
#      'name': 'Netta',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z4afeDmHFxPmJorIwupbZ'}],
#    'disc_number': 1,
#    'duration_ms': 200142,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRX282108742'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3scEZ2JrbtrqfUvgHrPnSt'},
#    'href': 'https://api.spotify.com/v1/tracks/3scEZ2JrbtrqfUvgHrPnSt',
#    'id': '3scEZ2JrbtrqfUvgHrPnSt',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'אפס מאמץ',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d27f8a39137eaa4c78277fc05f53d1120f35671d?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3scEZ2JrbtrqfUvgHrPnSt'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-17T13:18:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Hjbimq43OgxaBRpFXic4x'},
#       'href': 'https://api.spotify.com/v1/artists/7Hjbimq43OgxaBRpFXic4x',
#       'id': '7Hjbimq43OgxaBRpFXic4x',
#       'name': 'Saba',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Hjbimq43OgxaBRpFXic4x'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/10UscF31tC7Sz8S2a1mGbM'},
#     'href': 'https://api.spotify.com/v1/albums/10UscF31tC7Sz8S2a1mGbM',
#     'id': '10UscF31tC7Sz8S2a1mGbM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273eec9bfc96c9e0495b35e2257',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02eec9bfc96c9e0495b35e2257',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851eec9bfc96c9e0495b35e2257',
#       'width': 64}],
#     'name': 'Bucket List Project',
#     'release_date': '2016-10-27',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:10UscF31tC7Sz8S2a1mGbM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Hjbimq43OgxaBRpFXic4x'},
#      'href': 'https://api.spotify.com/v1/artists/7Hjbimq43OgxaBRpFXic4x',
#      'id': '7Hjbimq43OgxaBRpFXic4x',
#      'name': 'Saba',
#      'type': 'artist',
#      'uri': 'spotify:artist:7Hjbimq43OgxaBRpFXic4x'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4JqpJeNOhP6bAkolNMLwFg'},
#      'href': 'https://api.spotify.com/v1/artists/4JqpJeNOhP6bAkolNMLwFg',
#      'id': '4JqpJeNOhP6bAkolNMLwFg',
#      'name': 'Jean Deaux',
#      'type': 'artist',
#      'uri': 'spotify:artist:4JqpJeNOhP6bAkolNMLwFg'}],
#    'disc_number': 1,
#    'duration_ms': 201732,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUYG1115900'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3DlgDXIYtnWtJKiB8bZQMv'},
#    'href': 'https://api.spotify.com/v1/tracks/3DlgDXIYtnWtJKiB8bZQMv',
#    'id': '3DlgDXIYtnWtJKiB8bZQMv',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Photosynthesis',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/68d3edc112dccdf8ed9756178aa06ae61ae35827?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:3DlgDXIYtnWtJKiB8bZQMv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-01-19T09:30:38Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IAEef07H0fd9aA8aUHUlL'},
#       'href': 'https://api.spotify.com/v1/artists/1IAEef07H0fd9aA8aUHUlL',
#       'id': '1IAEef07H0fd9aA8aUHUlL',
#       'name': 'Omer Adam',
#       'type': 'artist',
#       'uri': 'spotify:artist:1IAEef07H0fd9aA8aUHUlL'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0g5N7b5TIJx058BMwVMAu3'},
#     'href': 'https://api.spotify.com/v1/albums/0g5N7b5TIJx058BMwVMAu3',
#     'id': '0g5N7b5TIJx058BMwVMAu3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fffa82e73f25160bdc5cca89',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fffa82e73f25160bdc5cca89',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fffa82e73f25160bdc5cca89',
#       'width': 64}],
#     'name': 'אחרי כל השנים',
#     'release_date': '2017-02-01',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:0g5N7b5TIJx058BMwVMAu3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1IAEef07H0fd9aA8aUHUlL'},
#      'href': 'https://api.spotify.com/v1/artists/1IAEef07H0fd9aA8aUHUlL',
#      'id': '1IAEef07H0fd9aA8aUHUlL',
#      'name': 'Omer Adam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1IAEef07H0fd9aA8aUHUlL'}],
#    'disc_number': 1,
#    'duration_ms': 216026,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'IL5301700159'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4XoF9s9DkvAyGEMc9fpsVn'},
#    'href': 'https://api.spotify.com/v1/tracks/4XoF9s9DkvAyGEMc9fpsVn',
#    'id': '4XoF9s9DkvAyGEMc9fpsVn',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'אף אחד לא יושב פה',
#    'popularity': 37,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d7647f5439df70639a86bf0046bad3841b482355?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:4XoF9s9DkvAyGEMc9fpsVn'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-01-19T13:30:57Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/solenita'},
#    'href': 'https://api.spotify.com/v1/users/solenita',
#    'id': 'solenita',
#    'type': 'user',
#    'uri': 'spotify:user:solenita'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7hD6dkjWHapWVwkI6bjDFo'},
#       'href': 'https://api.spotify.com/v1/artists/7hD6dkjWHapWVwkI6bjDFo',
#       'id': '7hD6dkjWHapWVwkI6bjDFo',
#       'name': 'Ran Danker',
#       'type': 'artist',
#       'uri': 'spotify:artist:7hD6dkjWHapWVwkI6bjDFo'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7MWnnnirr0o9KspAcOMPzG'},
#     'href': 'https://api.spotify.com/v1/albums/7MWnnnirr0o9KspAcOMPzG',
#     'id': '7MWnnnirr0o9KspAcOMPzG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731e0d8301912ff99afe82883d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021e0d8301912ff99afe82883d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511e0d8301912ff99afe82883d',
#       'width': 64}],
#     'name': 'השמלה החדשה שלי',
#     'release_date': '2021-10-18',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7MWnnnirr0o9KspAcOMPzG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7hD6dkjWHapWVwkI6bjDFo'},
#      'href': 'https://api.spotify.com/v1/artists/7hD6dkjWHapWVwkI6bjDFo',
#      'id': '7hD6dkjWHapWVwkI6bjDFo',
#      'name': 'Ran Danker',
#      'type': 'artist',
#      'uri': 'spotify:artist:7hD6dkjWHapWVwkI6bjDFo'}],
#    'disc_number': 1,
#    'duration_ms': 172024,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'IL1012100852'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0Cq5UOSrvfzJN5pUWx8Prb'},
#    'href': 'https://api.spotify.com/v1/tracks/0Cq5UOSrvfzJN5pUWx8Prb',
#    'id': '0Cq5UOSrvfzJN5pUWx8Prb',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'השמלה החדשה שלי',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/25f2d9e952c4dd48168cb6085186fd0330fcc10c?cid=2b56d6e548bf4f0ca8a909428b1a3ea4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0Cq5UOSrvfzJN5pUWx8Prb'},
#   'video_thumbnail': {'url': None}}]

# %%
for i in range(len(chillpill_tracks)):
    if chillpill_tracks[i]["track"]["id"] != None:
        audio_feature_dict = sp.audio_features(chillpill_tracks[i]["track"]["uri"])[0]
        my_dict_new = { key: [audio_feature_dict[key]] for key in list(audio_feature_dict.keys()) }
        new_df = pd.DataFrame(my_dict_new)
        df = df.append(new_df, ignore_index=True, sort=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      706 non-null    float64
#  1   energy            706 non-null    float64
#  2   key               706 non-null    int64
#  3   loudness          706 non-null    float64
#  4   mode              706 non-null    int64
#  5   speechiness       706 non-null    float64
#  6   acousticness      706 non-null    float64
#  7   instrumentalness  706 non-null    float64
#  8   liveness          706 non-null    float64
#  9   valence           706 non-null    float64
#  10  tempo             706 non-null    float64
#  11  type              706 non-null    object
#  12  id                706 non-null    object
#  13  uri               706 non-null    object
#  14  track_href        706 non-null    object
#  15  analysis_url      706 non-null    object
#  16  duration_ms       706 non-null    int64
#  17  time_signature    706 non-null    int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 99.4+ KB
